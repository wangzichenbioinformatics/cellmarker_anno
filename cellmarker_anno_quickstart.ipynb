# %%
from cellmarker_anno import get_plot_celltype_percent
# Out:
# cellmarker_dataset directory already exists.
# cellmarker_dataset/Mouse_cell_markers.txt data file already exists.

# %%
gene_name=['Esam','Vwf','Pcam1']
get_plot_celltype_percent(gene_name,figsize=(20,12))
get_plot_celltype_percent(gene_name)
